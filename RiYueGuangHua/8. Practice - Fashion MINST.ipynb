# %% [markdown]
# # 基于 Fashion MINST 的全连接模型

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
# 导入torchvision库
from torchvision import datasets, transforms
# 定义一个转换函数，将图像转换为张量（Tensor）
transformation = transforms.Compose([
                                transforms.ToTensor(),  # transforms.ToTensor()会将图像转换为张量，并且将像素值缩放到0-1之间，并且将channel放在第一维度上
                                # transforms.Normalize((0.5,), (0.5,))  # transforms.Normalize()会将图像的像素值进行标准化，即将像素值减去均值，然后除以标准差
])

# 从datasets模块中导入MNIST数据集
# 训练集
train_ds = datasets.FashionMNIST(
                          # 数据集的存储路径
                          'dataset/',
                          # 是否为训练集
                          train=True,
                          # 数据集的转换函数
                          transform=transformation,
                          # 是否下载数据集
                          download=True  
)
# 测试集
test_ds = datasets.FashionMNIST(
                          'dataset/',
                          train=False,
                          transform=transformation,
                          download=True  
)

# %%
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=64, shuffle=True) # 对dataset进行封装，将数据批量加载，batch_size为64，shuffle为True表示打乱数据集
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=64)

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.liner_1 = nn.Linear(28*28, 120)    # 输入层到隐藏层，全连接层，超参数选择为120
        self.liner_2 = nn.Linear(120, 84)       # 隐藏层到隐藏层，超参数选择为84
        self.liner_3 = nn.Linear(84, 10)        # 隐藏层到输出层，分类数为10
    def forward(self, input):
        x = input.view(-1, 28*28)               # 将输入的图片展平，将channel维度去掉，将hight和width维度合并为一个维度 28*28
        x = F.relu(self.liner_1(x))             # 第一层，激活函数为ReLU
        x = F.relu(self.liner_2(x))             # 第二层，激活函数为ReLU
        logits = self.liner_3(x)                # 输出层，不使用激活函数，未激活的输出通常被称为logits
        return logits

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # 判断是否有GPU，如果有则使用GPU，否则使用CPU
model = Model().to(device) # 将模型移动到GPU上实例化模型

loss_fn = torch.nn.CrossEntropyLoss()  # 损失函数，交叉熵损失函数，使用未激活的输出作为输入，内置了softmax函数为激活函数，输出为每个类别的概率
# opt = torch.optim.Adam(model.parameters(), lr=0.001) # 优化器，Adam优化器，学习率为0.001
opt = torch.optim.SGD(model.parameters(), lr=0.001) # 优化器，SGD优化器，学习率为0.001

# %%
# 训练前准备，定义模型、损失函数、优化器
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # 判断是否有GPU，如果有则使用GPU，否则使用CPU
model = Model().to(device) # 将模型移动到GPU上实例化模型

loss_fn = torch.nn.CrossEntropyLoss()  # 损失函数，交叉熵损失函数，使用未激活的输出作为输入，内置了softmax函数为激活函数，输出为每个类别的概率
opt = torch.optim.SGD(model.parameters(), lr=0.001) # 优化器，SGD优化器，学习率为0.001
epochs = 50

# 通用训练模板，输入模型、训练数据、测试数据，返回loss和acc变化
# 训练函数
def train(train_dl, model, loss_fn, opt):
    size = len(train_dl.dataset) # 获取数据集的大小
    num_batches = len(train_dl) # 获取数据集的批次数量

    train_loss = 0.0 # 训练集损失
    train_acc = 0.0 # 训练集准确率

    for x, y in train_dl: # 遍历数据集
        x, y = x.to(device), y.to(device) # 将数据移动到GPU上

        pred = model(x) # 前向传播
        loss = loss_fn(pred, y) # 计算损失

        opt.zero_grad() # 梯度清零
        loss.backward() # 反向传播
        opt.step() # 更新参数

        with torch.no_grad(): # 不计算梯度
            train_loss += loss.item() # 计算损失
            train_acc += (pred.argmax(dim=1) == y).type(torch.float).sum().item() # 计算准确率

    train_loss /= num_batches # 计算平均损失
    train_acc /= size # 计算平均准确率

    return train_loss, train_acc

# 测试函数
def test(test_dl, model, loss_fn):
    size = len(test_dl.dataset) # 获取数据集的大小
    num_batches = len(test_dl) # 获取数据集的批次数量

    test_loss = 0.0 # 测试集损失
    test_acc = 0.0 # 测试集准确率

    with torch.no_grad(): # 不计算梯度
        for x, y in test_dl: # 遍历数据集
            x, y = x.to(device), y.to(device) # 将数据移动到GPU上

            pred = model(x) # 前向传播
            loss = loss_fn(pred, y) # 计算损失
            test_loss += loss.item() # 计算损失
            test_acc += (pred.argmax(dim=1) == y).type(torch.float).sum().item() # 计算准确率

    test_loss /= num_batches # 计算平均损失
    test_acc /= size # 计算平均准确率

    return test_loss, test_acc

# 训练函数
def fit(epochs, model, train_dl, test_dl, loss_fn, opt):
    train_loss = []
    train_acc = []
    test_loss = []
    test_acc = []

    print_template = 'Epoch: {}, Train Loss: {:.4f}, Train Acc: {:.2f}%, Test Loss: {:.4f}, Test Acc: {:.2f}%'


    for epoch in range(epochs):
        epoch_train_loss, epoch_train_acc = train(train_dl, model, loss_fn, opt)
        epoch_test_loss, epoch_test_acc = test(test_dl, model, loss_fn)

        train_loss.append(epoch_train_loss)
        train_acc.append(epoch_train_acc)
        test_loss.append(epoch_test_loss)
        test_acc.append(epoch_test_acc)

        print(print_template.format(epoch, epoch_train_loss, epoch_train_acc * 100, epoch_test_loss, epoch_test_acc * 100))

    return train_loss, train_acc, test_loss, test_acc

# 训练
train_loss, train_acc, test_loss, test_acc = fit(epochs, model, train_dl, test_dl, loss_fn, opt)
# Out:
# Epoch: 0, Train Loss: 2.2520, Train Acc: 24.15%, Test Loss: 2.1985, Test Acc: 35.47%
# Epoch: 1, Train Loss: 2.1169, Train Acc: 45.34%, Test Loss: 2.0147, Test Acc: 49.27%
# Epoch: 2, Train Loss: 1.8683, Train Acc: 47.49%, Test Loss: 1.7118, Test Acc: 46.87%
# Epoch: 3, Train Loss: 1.5611, Train Acc: 51.05%, Test Loss: 1.4318, Test Acc: 55.99%
# Epoch: 4, Train Loss: 1.3253, Train Acc: 60.15%, Test Loss: 1.2424, Test Acc: 60.59%
# Epoch: 5, Train Loss: 1.1676, Train Acc: 63.21%, Test Loss: 1.1145, Test Acc: 63.41%
# Epoch: 6, Train Loss: 1.0567, Train Acc: 65.11%, Test Loss: 1.0214, Test Acc: 65.16%
# Epoch: 7, Train Loss: 0.9736, Train Acc: 66.62%, Test Loss: 0.9502, Test Acc: 65.43%
# Epoch: 8, Train Loss: 0.9103, Train Acc: 67.91%, Test Loss: 0.8951, Test Acc: 67.29%
# Epoch: 9, Train Loss: 0.8608, Train Acc: 69.34%, Test Loss: 0.8525, Test Acc: 69.07%
# Epoch: 10, Train Loss: 0.8215, Train Acc: 70.58%, Test Loss: 0.8185, Test Acc: 69.43%
# Epoch: 11, Train Loss: 0.7898, Train Acc: 71.69%, Test Loss: 0.7899, Test Acc: 71.15%
# Epoch: 12, Train Loss: 0.7631, Train Acc: 72.72%, Test Loss: 0.7661, Test Acc: 72.11%
# Epoch: 13, Train Loss: 0.7404, Train Acc: 73.66%, Test Loss: 0.7450, Test Acc: 73.29%
# Epoch: 14, Train Loss: 0.7206, Train Acc: 74.53%, Test Loss: 0.7271, Test Acc: 74.00%
# Epoch: 15, Train Loss: 0.7028, Train Acc: 75.31%, Test Loss: 0.7111, Test Acc: 74.53%
# Epoch: 16, Train Loss: 0.6868, Train Acc: 75.96%, Test Loss: 0.6964, Test Acc: 74.93%
# Epoch: 17, Train Loss: 0.6717, Train Acc: 76.45%, Test Loss: 0.6820, Test Acc: 75.86%
# Epoch: 18, Train Loss: 0.6579, Train Acc: 77.07%, Test Loss: 0.6691, Test Acc: 76.44%
# Epoch: 19, Train Loss: 0.6452, Train Acc: 77.61%, Test Loss: 0.6568, Test Acc: 76.58%
# Epoch: 20, Train Loss: 0.6333, Train Acc: 78.08%, Test Loss: 0.6460, Test Acc: 77.16%
# Epoch: 21, Train Loss: 0.6220, Train Acc: 78.51%, Test Loss: 0.6354, Test Acc: 77.57%
# Epoch: 22, Train Loss: 0.6119, Train Acc: 78.93%, Test Loss: 0.6258, Test Acc: 77.96%
# Epoch: 23, Train Loss: 0.6020, Train Acc: 79.33%, Test Loss: 0.6183, Test Acc: 78.32%
# Epoch: 24, Train Loss: 0.5932, Train Acc: 79.71%, Test Loss: 0.6100, Test Acc: 78.74%
# Epoch: 25, Train Loss: 0.5846, Train Acc: 80.11%, Test Loss: 0.6009, Test Acc: 78.94%
# Epoch: 26, Train Loss: 0.5768, Train Acc: 80.25%, Test Loss: 0.5949, Test Acc: 79.11%
# Epoch: 27, Train Loss: 0.5692, Train Acc: 80.52%, Test Loss: 0.5880, Test Acc: 79.41%
# Epoch: 28, Train Loss: 0.5623, Train Acc: 80.83%, Test Loss: 0.5819, Test Acc: 79.64%
# Epoch: 29, Train Loss: 0.5557, Train Acc: 81.01%, Test Loss: 0.5756, Test Acc: 80.03%
# Epoch: 30, Train Loss: 0.5494, Train Acc: 81.29%, Test Loss: 0.5696, Test Acc: 80.19%
# Epoch: 31, Train Loss: 0.5436, Train Acc: 81.44%, Test Loss: 0.5659, Test Acc: 80.47%
# Epoch: 32, Train Loss: 0.5381, Train Acc: 81.65%, Test Loss: 0.5589, Test Acc: 80.60%
# Epoch: 33, Train Loss: 0.5329, Train Acc: 81.75%, Test Loss: 0.5559, Test Acc: 80.51%
# Epoch: 34, Train Loss: 0.5279, Train Acc: 81.93%, Test Loss: 0.5530, Test Acc: 80.52%
# Epoch: 35, Train Loss: 0.5235, Train Acc: 82.10%, Test Loss: 0.5453, Test Acc: 81.09%
# Epoch: 36, Train Loss: 0.5191, Train Acc: 82.23%, Test Loss: 0.5421, Test Acc: 81.12%
# Epoch: 37, Train Loss: 0.5149, Train Acc: 82.34%, Test Loss: 0.5374, Test Acc: 81.36%
# Epoch: 38, Train Loss: 0.5109, Train Acc: 82.46%, Test Loss: 0.5351, Test Acc: 81.17%
# Epoch: 39, Train Loss: 0.5070, Train Acc: 82.56%, Test Loss: 0.5315, Test Acc: 81.43%
# Epoch: 40, Train Loss: 0.5035, Train Acc: 82.70%, Test Loss: 0.5279, Test Acc: 81.58%
# Epoch: 41, Train Loss: 0.5001, Train Acc: 82.84%, Test Loss: 0.5247, Test Acc: 81.70%
# Epoch: 42, Train Loss: 0.4970, Train Acc: 82.80%, Test Loss: 0.5240, Test Acc: 81.21%
# Epoch: 43, Train Loss: 0.4941, Train Acc: 82.98%, Test Loss: 0.5187, Test Acc: 81.79%
# Epoch: 44, Train Loss: 0.4907, Train Acc: 83.08%, Test Loss: 0.5167, Test Acc: 81.98%
# Epoch: 45, Train Loss: 0.4879, Train Acc: 83.18%, Test Loss: 0.5146, Test Acc: 81.79%
# Epoch: 46, Train Loss: 0.4854, Train Acc: 83.15%, Test Loss: 0.5120, Test Acc: 81.71%
# Epoch: 47, Train Loss: 0.4829, Train Acc: 83.28%, Test Loss: 0.5104, Test Acc: 81.77%
# Epoch: 48, Train Loss: 0.4803, Train Acc: 83.34%, Test Loss: 0.5082, Test Acc: 82.15%
# Epoch: 49, Train Loss: 0.4783, Train Acc: 83.45%, Test Loss: 0.5049, Test Acc: 82.06%

# %%
plt.plot(range(epochs), train_loss, label='Train Loss')
plt.plot(range(epochs), test_loss, label='Test Loss')
plt.legend()

# %%
plt.plot(range(epochs), train_acc, label='Train Accuracy')
plt.plot(range(epochs), test_acc, label='Test Accuracy')
plt.legend()
